# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module4- Lab5

# %%
# %matplotlib notebook
import pandas as pd

from scipy import misc
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import matplotlib.pyplot as plt
import imageio

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# Create a regular Python list (not NDArray) and name it `samples`:

# %%
samples = []# .. your code here ..

# %% [markdown]
# Code up a for-loop that iterates over the images in the `Datasets/ALOI/32/` folder. Look in the folder first, so you know how the files are organized, and what file number they start from and end at.
#
# Load each `.png` file individually in your for-loop using the instructions provided in the Feature Representation reading. Once loaded, flatten the image into a single-dimensional NDArray and append it to your `samples` list.
#
# **Optional**: You can resample the image down by a factor of two if you have a slower computer. You can also scale the image from `0-255` to `0.0-1.0` if you'd like--doing so shouldn't have any effect on the algorithm's results.

# %%
# #your path

folder = 'C:\\Users\\Akshay\\Desktop\\PyFinance\\DAT210x\\DAT210x-master\\Module4\\Datasets\\ALOI\\32'
# for fname in col_dir:
#   img = imageio.imread(fname)
#   samples.append(  (img[::2, ::2] / 255.0).reshape(-1)  )
# #samples = pd.DataFrame( dset )# .. your code here ..
import sys
import cv2
import numpy as np
import os

samples = []
for filename in os.listdir(folder):
        img = imageio.imread(os.path.join(folder,filename))
        if img is not None:
            samples.append((img[::2, ::2] / 255.0).reshape(-1))

# %% [markdown]
# Convert `samples` to a DataFrame named `df`:

# %%
df = pd.DataFrame(samples)# .. your code here ..

# %%
df.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.015686  0.015686  0.011765  0.011765  0.011765  0.011765  0.011765
# 1  0.015686  0.015686  0.015686  0.011765  0.015686  0.011765  0.011765
# 2  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 3  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 4  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
#
#        7         8         9       ...         6902      6903      6904  \
# 0  0.011765  0.011765  0.011765    ...     0.054902  0.050980  0.050980
# 1  0.015686  0.015686  0.015686    ...     0.050980  0.054902  0.050980
# 2  0.015686  0.015686  0.015686    ...     0.050980  0.050980  0.047059
# 3  0.015686  0.015686  0.015686    ...     0.047059  0.047059  0.047059
# 4  0.015686  0.015686  0.015686    ...     0.047059  0.047059  0.047059
#
#        6905      6906      6907      6908      6909      6910      6911
# 0  0.050980  0.047059  0.050980  0.047059  0.050980  0.050980  0.047059
# 1  0.050980  0.050980  0.054902  0.050980  0.050980  0.050980  0.050980
# 2  0.050980  0.050980  0.050980  0.047059  0.047059  0.047059  0.047059
# 3  0.047059  0.047059  0.047059  0.050980  0.047059  0.047059  0.047059
# 4  0.047059  0.043137  0.047059  0.047059  0.047059  0.047059  0.043137
#
# [5 rows x 6912 columns]

# %% [markdown]
# Import any necessary libraries to perform Isomap here, reduce `df` down to three components and using `K=6` for your neighborhood size:

# %%
# .. your code here ..
from sklearn.manifold import Isomap
iso = Isomap(n_components = 3, n_neighbors = 2)
iso.fit(df)
T1 = iso.transform(df)

# %%
T1=pd.DataFrame(T1)

# %% [markdown]
# Create a 2D Scatter plot to graph your manifold. You can use either `'o'` or `'.'` as your marker. Graph the first two isomap components:

# %%
# .. your code here ..
T1.columns = ['component1', 'component2', 'component3']
T1.plot.scatter(x='component1', y='component2', marker='o')
plt.suptitle('Component 1 vs 2')
plt.xlabel('PC_1')
plt.ylabel('PC_2')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Chart a 3D Scatter plot to graph your manifold. You can use either `'o'` or `'.'` as your marker:

# %%
# .. your code here ..
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
	
ax.scatter(T1.component1, T1.component2, T1.component3, c='r', marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Answer the first two lab questions!

# %% [markdown]
# Create another for loop. This time it should iterate over all the images in the `Datasets/ALOI/32_i` directory. Just like last time, load up each image, process them the way you did previously, and append them into your existing `samples` list:

# %%
# .. your code here ..
newfolder = 'C:\\Users\\Akshay\\Desktop\\PyFinance\\DAT210x\\DAT210x-master\\Module4\\Datasets\\ALOI\\32i'
for filename in os.listdir(newfolder):
    img = imageio.imread(os.path.join(newfolder,filename))
    if img is not None:
        samples.append((img[::2, ::2] / 255.0).reshape(-1))

# %% [markdown]
# Convert `samples` to a DataFrame named `df`:

# %%
df = pd.DataFrame(samples)# .. your code here ..

# %% [markdown]
# Import any necessary libraries to perform Isomap here, reduce `df` down to three components and using `K=6` for your neighborhood size:

# %%
# .. your code here ..
from sklearn.manifold import Isomap
iso = Isomap(n_components = 3, n_neighbors = 6)
iso.fit(df)
T1 = iso.transform(df)

# %% [markdown]
# Create a 2D Scatter plot to graph your manifold. You can use either `'o'` or `'.'` as your marker. Graph the first two isomap components:

# %%
# .. your code here ..
T1 = pd.DataFrame(T1)
T1.columns = ['component1', 'component2', 'component3']
T1.plot.scatter(x='component1', y='component2', marker='o')
plt.suptitle('Component 1 vs 2')
plt.xlabel('PC_1')
plt.ylabel('PC_2')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Chart a 3D Scatter plot to graph your manifold. You can use either `'o'` or `'.'` as your marker:

# %%
# .. your code here ..
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
	
ax.scatter(T1.component1, T1.component2, T1.component3, c='r', marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
